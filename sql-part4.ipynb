-- %% [markdown]
-- # Exercises: Complex queries
--
-- For the exercises, you are tasked with writing five queries that will help you delve deeper into BooksDB. You can choose whether you want to use a correlated subquery, a nested subquery, the UNION operator, the INTERSECT operator, or the EXCEPT operator for each one. You may not use joins or add multiple statements to the WHERE clause.
--
-- 1. Write a query that will return the number of users who rated a book above it's average rating.

-- %%
-- select * from BooksDB.dbo.ratings
-- select * from BooksDB.dbo.books

-- select * from BooksDB.dbo.ratings where rating>(select average_rating from BooksDB.dbo.books where 
-- BooksDB.dbo.books.book_id=BooksDB.dbo.ratings.book_id)

 --select count(user_id) from BooksDB.dbo.ratings where rating>(select average_rating from BooksDB.dbo.books where 
-- BooksDB.dbo.books.book_id=BooksDB.dbo.ratings.book_id) Ans:40960, here userid is repetive

-- select distinct user_id from BooksDB.dbo.ratings where rating>(select average_rating from BooksDB.dbo.books where 
-- BooksDB.dbo.books.book_id=BooksDB.dbo.ratings.book_id)

--these are the steps taken to solve this question

 select count(distinct user_id) as Number_of_users_who_rated_a_book_above_its_average_rating from BooksDB.dbo.ratings 
 where rating>(select average_rating from BooksDB.dbo.books where 
BooksDB.dbo.books.book_id=BooksDB.dbo.ratings.book_id)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.571
-- <table><tr><th>Number_of_users_who_rated_a_book_above_its_average_rating</th></tr><tr><td>19926</td></tr></table>

-- %% [markdown]
-- 2. Write a query that returns the book ids of all books that have over 1000 ratings of 1 star or over 1000 ratings of 5 stars.

-- %%
--select count(*) from BooksDB.dbo.books
--Ans: 10000 

--from analysis, work_text_reviews_count=ratings_1+ratings_2+ratings_3+ratings_4+ratings_5

--select * from BooksDB.dbo.books where ratings_1>1000
--//Ans:2238 rows

--select * from BooksDB.dbo.books where ratings_5>1000
--//Ans:9994 rows

--select * from BooksDB.dbo.books where ratings_1>1000 and ratings_5>1000
--//Ans:2234 rows

--  select * from BooksDB.dbo.books where 
-- ratings_1 in (select BooksDB.dbo.books.ratings_1 from BooksDB.dbo.books where BooksDB.dbo.books.ratings_1>1000)
--//Ans:2238 rows

select book_id from BooksDB.dbo.books where BooksDB.dbo.books.ratings_1>1000 or BooksDB.dbo.books.ratings_5>1000
--9998 rows
-- Out:
-- (9998 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.180
-- ...

-- %% [markdown]
-- 3. Write a query that returns the book ids of all books that have over 1000 ratings of 1 star and over 1000 ratings of 5 stars.

-- %%
select book_id from BooksDB.dbo.books where BooksDB.dbo.books.ratings_1>1000 and BooksDB.dbo.books.ratings_5>1000
--2234 rows
-- Out:
-- (2234 rows affected)
-- Total execution time: 00:00:00.092
-- ...

-- %% [markdown]
-- 4. Write a query that returns the book ids of books that have a language code of "en-US" and not a langugae code of "en-GB".

-- %%
--select * from BooksDB.dbo.books where BooksDB.dbo.books.language_code='en-US' 
--Ans:2070 rows

--select * from BooksDB.dbo.books where BooksDB.dbo.books.language_code='en-GB' 
--Ans:257 rows

--select book_id from BooksDB.dbo.books where BooksDB.dbo.books.language_code='en-US' and BooksDB.dbo.books.language_code<>'en-GB'
--Ans:2070 rows

select book_id from BooksDB.dbo.books where BooksDB.dbo.books.language_code in(select BooksDB.dbo.books.language_code from 
BooksDB.dbo.books where BooksDB.dbo.books.language_code='en-US' and BooksDB.dbo.books.language_code<>'en-GB')
--Ans:2070 rows
-- Out:
-- (2070 rows affected)
-- Total execution time: 00:00:00.161
-- ...

-- %% [markdown]
-- 5. Write a query that returns the names of the tags and the tag ids for tags that were used over 100,000 times for a book.

-- %%
--select * from BooksDB.dbo.book_tags where count>100000
--Ans:207 rows

-- select BooksDB.dbo.tags.tag_id, BooksDB.dbo.book_tags.tag_id, BooksDB.dbo.tags.tag_name,BooksDB.dbo.book_tags.count from 
-- BooksDB.dbo.tags join 
-- BooksDB.dbo.book_tags  on
-- BooksDB.dbo.book_tags.tag_id=BooksDB.dbo.tags.tag_id where BooksDB.dbo.book_tags.count>100000
--Ans:207 rows, here I did not used sub query or correlated query.

--select BooksDB.dbo.book_tags.goodreads_book_id,BooksDB.dbo.book_tags.tag_id,BooksDB.dbo.book_tags.count from BooksDB.dbo.book_tags where BooksDB.dbo.book_tags.count>100000

--select *  from BooksDB.dbo.tags

    select BooksDB.dbo.tags.tag_id, BooksDB.dbo.tags.tag_name from 
BooksDB.dbo.tags where BooksDB.dbo.tags.tag_id  in(
    select BooksDB.dbo.book_tags.tag_id from BooksDB.dbo.book_tags where BooksDB.dbo.book_tags.count>100000)



--Ans:1 row
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.141
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>30574</td><td>to-read</td></tr></table>
